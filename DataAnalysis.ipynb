# %% [markdown]
# # Brand Platform URL

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data1=pd.read_csv('Brand-Platform-URL.csv')

# %%
data1
# Out:
#           Brand                    Market Platform  \
# 0    germanrosy  United States of America  Twitter
# 1      carslord                     India  Twitter
# 2       vandawn                 Argentina  Twitter
# 3      aquapeak                   Austria  Twitter
# 4      dualjape                Azerbaijan  Twitter
# ..          ...                       ...      ...
# 417    handfoxy                   Denmark  YouTube
# 418    handfoxy                   Ecuador  YouTube
# 419    handfoxy               El Salvador  YouTube
# 420    handfoxy                   Finland  YouTube
# 421    handfoxy                    France  YouTube
#
#                                                URL
# 0                               twitter.com/_gr_SA
# 1                               twitter.com/_idand
# 2                               twitter.com/_nluay
# 3                               twitter.com/elllub
# 4                               twitter.com/_SAina
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brand     422 non-null    object
#  1   Market    422 non-null    object
#  2   Platform  422 non-null    object
#  3   URL       422 non-null    object
# dtypes: object(4)
# memory usage: 13.3+ KB

# %%
data1.describe()
# Out:
#            Brand                    Market Platform                 URL
# count        422                       422      422                 422
# unique        12                        93        2                 422
# top     dualjape  United States of America  YouTube  twitter.com/_gr_SA
# freq          91                        19      262                   1

# %%
data1['Market'].value_counts()
# Out:
# United States of America                               19
# United Kingdom of Great Britain and Northern Island    14
# India                                                  12
# Global                                                 12
# Paraguay                                               10
#                                                        ..
# Guatemala                                               1
# Malta                                                   1
# Korea, Republic of                                      1
# Venezuela, Bolivarian Republic of                       1
# Iran, Islamic Rupublic of                               1
# Name: Market, Length: 93, dtype: int64

# %%
data1['Brand'].unique()
# Out:
# array(['germanrosy', 'carslord', 'vandawn', 'aquapeak', 'dualjape',
#        'weiwind', 'osvent', 'songseem', 'handfoxy', 'techfond',
#        'ironsoft', 'bassvest'], dtype=object)

# %%
data1['Brand'].value_counts()
# Out:
# dualjape      91
# aquapeak      72
# handfoxy      68
# ironsoft      40
# techfond      38
# germanrosy    37
# weiwind       21
# songseem      15
# carslord      13
# bassvest      12
# vandawn       11
# osvent         4
# Name: Brand, dtype: int64

# %%
data1['Platform'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
def analysis(df,col,vartype,hue =None):    
    sns.set(style="darkgrid")
    if vartype == 0:
        fig, ax=plt.subplots(nrows =1,ncols=3,figsize=(20,8))
        ax[0].set_title("Distribution Plot")
        sns.distplot(df[col],ax=ax[0])
        ax[1].set_title("Violin Plot")
        sns.violinplot(data =df, x=col,ax=ax[1], inner="quartile")
        ax[2].set_title("Box Plot")
        sns.boxplot(data =df, x=col,ax=ax[2],orient='v')
    if vartype == 1:
        temp = pd.Series(data = hue,dtype=object)
        fig, ax = plt.subplots()
        width = len(df[col].unique()) + 10 + 10*len(temp.unique())
        fig.set_size_inches(width , 10)
        ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue) 
        if len(temp.unique()) > 0:
#             for p in ax.patches:
#                 ax.annotate('{:1.1f}%'.format((p.get_height()*100)/float(len(loan))), (p.get_x()+0.30, p.get_height()+20))  
#         else:
            for p in ax.patches:
                ax.annotate(p.get_height(), (p.get_x()+0.50, p.get_height()+2))
        del temp
    else:
        exit
    plt.show()

# %%
analysis(df=data1,col='Brand',vartype=1)

# %%
data1['Platform'].unique()
# Out:
# array(['Twitter', 'YouTube'], dtype=object)

# %%
brand_list=[]
platform_youtube=[]
platform_twitter=[]

for brand in data1['Brand'].unique():
    for platform in data1['Platform'].unique():
        if brand not in brand_list:
            brand_list.append(brand) 
        if (platform=='Twitter'):
            platform_twitter.append(len(data1[(data1['Brand']==brand) & (data1['Platform']=='Twitter')]))
        if (platform=='YouTube'):
            platform_youtube.append(len(data1[(data1['Brand']==brand) & (data1['Platform']=='YouTube')]))
        
        print(brand + ' brand for the platform ' + platform + ' is ',len(data1[(data1['Brand']==brand) & (data1['Platform']==platform)]))
# Out:
# germanrosy brand for the platform Twitter is  12
# germanrosy brand for the platform YouTube is  25
# carslord brand for the platform Twitter is  7
# carslord brand for the platform YouTube is  6
# vandawn brand for the platform Twitter is  5
# vandawn brand for the platform YouTube is  6
# aquapeak brand for the platform Twitter is  30
# aquapeak brand for the platform YouTube is  42
# dualjape brand for the platform Twitter is  37
# dualjape brand for the platform YouTube is  54
# weiwind brand for the platform Twitter is  6
# weiwind brand for the platform YouTube is  15
# osvent brand for the platform Twitter is  1
# osvent brand for the platform YouTube is  3
# songseem brand for the platform Twitter is  5
# songseem brand for the platform YouTube is  10
# handfoxy brand for the platform Twitter is  22
# handfoxy brand for the platform YouTube is  46
# techfond brand for the platform Twitter is  13
# techfond brand for the platform YouTube is  25
# ...

# %%
list(zip(platform_youtube,platform_twitter))
# Out:
# [(25, 12),
#  (6, 7),
#  (6, 5),
#  (42, 30),
#  (54, 37),
#  (15, 6),
#  (3, 1),
#  (10, 5),
#  (46, 22),
#  (25, 13),
#  (24, 16),
#  (6, 6)]

# %%
brand_list

df = pd.DataFrame({
    'Brand': brand_list,
    'Youtube': platform_youtube,
    'Twitter': platform_twitter
})
df
# Out:
#          Brand  Youtube  Twitter
# 0   germanrosy       25       12
# 1     carslord        6        7
# 2      vandawn        6        5
# 3     aquapeak       42       30
# 4     dualjape       54       37
# 5      weiwind       15        6
# 6       osvent        3        1
# 7     songseem       10        5
# 8     handfoxy       46       22
# 9     techfond       25       13
# 10    ironsoft       24       16
# 11    bassvest        6        6

# %%
df.plot(x="Brand", y=["Youtube", "Twitter"], kind="bar",figsize=(14,7))
# Out:
# <AxesSubplot:xlabel='Brand'>

# %% [markdown]
# # Twitter data

# %%
data2=pd.read_csv('Twitter Data.csv')
data2
# Out:
#                     URL Verified      Verified Accounts  Year Quarter  \
# 0    twitter.com/_gr_SA    False  Non Verified Accounts  2021   Qtr 1
# 1    twitter.com/_idand    False  Non Verified Accounts  2021   Qtr 1
# 2    twitter.com/_nluay     True      Verified Accounts  2021   Qtr 1
# 3    twitter.com/elllub     True      Verified Accounts  2021   Qtr 1
# 4    twitter.com/_SAina     True      Verified Accounts  2021   Qtr 1
# ..                  ...      ...                    ...   ...     ...
# 624     twitter.com/_jp     True      Verified Accounts  2021   Qtr 4
# 625     twitter.com/_jp     True      Verified Accounts  2022   Qtr 2
# 626  twitter.com/ejpnpy    False  Non Verified Accounts  2022   Qtr 2
# 627  twitter.com/ejpnpy     True      Verified Accounts  2021   Qtr 4
# 628  twitter.com/ejpnpy     True      Verified Accounts  2022   Qtr 1
#
#         Month  Day Name / ID                        Location  Has Description  \
# ...

# %%
data2[data2['Followers']==0.0]
# Out:
#                     URL Verified      Verified Accounts  Year Quarter  \
# 13   twitter.com/_ruico    False  Non Verified Accounts  2021   Qtr 1
# 85   twitter.com/adaypk    False  Non Verified Accounts  2021   Qtr 1
# 419  twitter.com/IDNmex    False  Non Verified Accounts  2021   Qtr 4
#
#         Month  Day Name / ID Location  Has Description  Followers  \
# 13      March    9       NaN      NaN  Has Description        0.0
# 85      March    9       NaN      NaN  Has Description        0.0
# 419  December   31  Dove_IDN      NaN   No Description        0.0
#
#     Status Available Accounts Without a Link
# 13              True                Has Link
# 85             False                 No Link
# 419             True                 No Link

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 629 entries, 0 to 628
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   URL                      629 non-null    object
#  1   Verified                 607 non-null    object
#  2   Verified Accounts        607 non-null    object
#  3   Year                     629 non-null    int64
#  4   Quarter                  629 non-null    object
#  5   Month                    629 non-null    object
#  6   Day                      629 non-null    int64
#  7   Name / ID                485 non-null    object
#  8   Location                 289 non-null    object
#  9   Has Description          629 non-null    object
#  10  Followers                607 non-null    float64
#  11  Status Available         607 non-null    object
#  12  Accounts Without a Link  629 non-null    object
# dtypes: float64(1), int64(2), object(10)
# ...

# %%
data_verified=data2[data2['Verified']==True]
data_nverified=data2[data2['Verified']==False]

# %%
fig, ax = plt.subplots(figsize=(6,6))

sns.histplot(data=data_nverified, 
             x='Month',
             bins=5,
             hue='Year',
             ax=ax)

plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(6,6))

sns.histplot(data=data_verified, 
             x='Month',
             bins=5,
             hue='Year',
             ax=ax)

plt.tight_layout()

# %%
data_verified=pd.DataFrame(data_verified.groupby(['Quarter','Month','Year']).sum())
data_verified.drop(['Day'],axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Quarter,Month,Year'>

# %%
data_nverified=pd.DataFrame(data_nverified.groupby(['Quarter','Month','Year']).sum())
data_nverified.drop(['Day'],axis=1).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Quarter,Month,Year'>

# %%
pd.DataFrame(data2.groupby(['Quarter','Month','Year','Accounts Without a Link']).sum()).drop('Day',axis=1)
# Out:
#                                                Followers
# Quarter Month    Year Accounts Without a Link
# Qtr 1   January  2022 Has Link                 1331037.0
#                       No Link                   100376.0
#         March    2021 Has Link                 1462261.0
#                       No Link                    66816.0
# Qtr 2   May      2022 Has Link                 1530270.0
#                       No Link                   156360.0
# Qtr 4   December 2021 Has Link                 1375595.0
#                       No Link                   100460.0

# %%
pd.DataFrame(data2.groupby(['Quarter','Month','Year','Has Description']).sum()).drop('Day',axis=1)
# Out:
#                                        Followers
# Quarter Month    Year Has Description
# Qtr 1   January  2022 Has Description  1340430.0
#                       No Description     90983.0
#         March    2021 Has Description  1528878.0
#                       No Description       199.0
# Qtr 2   May      2022 Has Description  1595987.0
#                       No Description     90643.0
# Qtr 4   December 2021 Has Description  1384878.0
#                       No Description     91177.0

# %% [markdown]
# ### Having description is more important than having link

# %% [markdown]
# # Youtube Views

# %%
data3=pd.read_csv('Youtube Views.csv')
data3.head()
# Out:
#                                      Channel URL  \
# 0  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2
# 1  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2
# 2  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2
# 3  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2
# 4  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2
#
#                        Video URL   Views  Year Quarter  Month  Day
# 0  youtube.com/watch?v=02dDB2JiM    4400  2021   Qtr 1  March   10
# 1  youtube.com/watch?v=0B6Cu1ReY    5679  2021   Qtr 1  March   10
# 2  youtube.com/watch?v=0Ijn787VY  485305  2021   Qtr 1  March   10
# 3  youtube.com/watch?v=19nt74y7M      62  2021   Qtr 1  March   10
# 4  youtube.com/watch?v=1dY1-4nPA    3356  2021   Qtr 1  March   10

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20315 entries, 0 to 20314
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Channel URL  20315 non-null  object
#  1   Video URL    20315 non-null  object
#  2   Views        20315 non-null  int64
#  3   Year         20315 non-null  int64
#  4   Quarter      20315 non-null  object
#  5   Month        20315 non-null  object
#  6   Day          20315 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 1.1+ MB

# %%
pd.DataFrame(data3.groupby(['Channel URL','Quarter','Month','Year']).sum()).drop('Day',axis=1)
# Out:
#                                                                      Views
# Channel URL                                   Quarter Month Year
# youtube.com/channel/UC-5JqPvEm526B_C-GwrxyfH5 Qtr 1   March 2021  37976112
# youtube.com/channel/UC-8XFVNi60SgPYA7wYdQz042 Qtr 1   March 2021  14197435
# youtube.com/channel/UC-N4P8XQE3klir2IZdrV8d-7 Qtr 1   March 2021  83062067
# youtube.com/channel/UC-fhDWis30S3WKhsr-QuDP77 Qtr 1   March 2021   3568461
# youtube.com/channel/UC-tDxn9o501WoPKhWYCWSws1 Qtr 1   March 2021    362834
# ...                                                                    ...
# youtube.com/channel/UCyTmlMnUz6uRhDOScjWlTXK6 Qtr 1   March 2021  23015283
# youtube.com/channel/UCykgkHudr5Vm9WbmCkZJWVr7 Qtr 1   March 2021  13269941
# youtube.com/channel/UCzZLWFeDp4twinDEP_-PMXM4 Qtr 1   March 2021  14681013
# youtube.com/channel/UCzb6eZ_hO2WqppMgzwJuk7b8 Qtr 1   March 2021   2823427
# youtube.com/channel/UCzhxyTK7z628ouWSchEV5Wc5 Qtr 1   March 2021   9668464
#
# ...

# %%
len(data3[data3['Views']<=100]) ####Less than 100 views
# Out:
# 1975

# %% [markdown]
# # Youtube Channel data

# %%
data4=pd.read_csv('Youtube Channel Data.csv')
data4
# Out:
#                                                 URL Channel Has Title  \
# 0      youtube.com/channel/UCcQgYUSp3PORuZIQBsXdk4A         Has Title
# 1      youtube.com/channel/UCcQgYUSp3PORuZIQBsXdk4A         Has Title
# 2      youtube.com/channel/UCcQgYUSp3PORuZIQBsXdk4A         Has Title
# 3      youtube.com/channel/UCcQgYUSp3PORuZIQBsXdk4A         Has Title
# 4      youtube.com/channel/UCcQgYUSp3PORuZIQBsXdk4A         Has Title
# ...                                             ...               ...
# 1105  youtube.com/channel/UC0bNByUj13rMW50t45AnCFc8         Has Title
# 1106  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2         Has Title
# 1107  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2         Has Title
# 1108  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2         Has Title
# 1109  youtube.com/channel/UC_KpTo38S7I2SwQgm1aqaQm2         Has Title
#
#       Has Description   Location  Year Quarter     Month  Day Is Verified  \
# ...

# %%
pd.DataFrame(data4.groupby(['Channel Has Title','Has Description','Year','Is Verified']).sum()).drop('Day',axis=1)
# Out:
#                                                     Subscriber
# Channel Has Title Has Description Year Is Verified
# Has Title         Has Description 2021 False         4985012.0
#                                        True           257434.0
#                                   2022 False        10115958.0
#                                        True           514945.0
#                   No Description  2021 False         1213135.0
#                                   2022 False         2430297.0

# %% [markdown]
# ### Even when the channels have description and not verified, in both the years 2021 and 2022, the number of subscribers are more when compared to the ones which are verified and have description considering the analysis as per the data when the channels have no descrition they can not be verified.

# %%
#Merging data

brand_market_analysis=pd.merge(data1,data2,how='inner',on='URL')
brand_market_analysis.to_csv('overall_brand.csv')
brand_market_analysis
# Out:
#           Brand                    Market Platform                 URL  \
# 0    germanrosy  United States of America  Twitter  twitter.com/_gr_SA
# 1    germanrosy  United States of America  Twitter  twitter.com/_gr_SA
# 2    germanrosy  United States of America  Twitter  twitter.com/_gr_SA
# 3    germanrosy  United States of America  Twitter  twitter.com/_gr_SA
# 4      carslord                     India  Twitter  twitter.com/_idand
# ..          ...                       ...      ...                 ...
# 624    bassvest              South Africa  Twitter     twitter.com/ile
# 625    handfoxy                     Spain  Twitter     twitter.com/dal
# 626    handfoxy                     Spain  Twitter     twitter.com/dal
# 627    handfoxy                     Spain  Twitter     twitter.com/dal
# 628    handfoxy                     Spain  Twitter     twitter.com/dal
#
#     Verified      Verified Accounts  Year Quarter     Month  Day  \
# ...
